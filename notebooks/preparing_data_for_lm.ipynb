# %%
from __future__ import division, absolute_import

import os
import sys
import random

import numpy as np

#root
absPath = '/home/angela/padding_EBI/'
sys.path.insert(0, absPath)

#from src.Target import Target

np.random.seed(8)
random.seed(8)

from src.preprocessing import *
from src.model_architecture import *
from src.training_model import *
from src.postprocessing import *
from src.comparing_results import *
#from src.callbacks import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Defining parameters

# %%
list_paddings = [
    'post_padding', 'pre_padding', 'mid_padding', 
    'strf_padding', 'ext_padding', 
                 'rnd_padding', 
                 'aug_padding',
                'zoom_padding'
                ]
#list_paddings = ['aug_padding']
#list_padding_short = ['post_padding', 'pre_padding', 'mid_padding', 'stretch_padding', 'ext_padding', 
#                 'rdm_padding']
#hierarchy of folders: annotation/dataset/architecture/n_neurs/task/padding
folder1 = 'EC_number/archaea/1conv/64filts_size5/' 
folder2 = 'EC_number/archaea/3denses/bio_neurons/'
folder3 = 'EC_number/archaea/rnn_conv/256rnn/'
folder4 = 'EC_number/archaea/stack_conv/10filts_sizeJurtz/'
column = "EC number"

n_folds = 10

dicti = creating_dict()

max_lenn = 1000

# %%
folders = [folder1, folder2, folder3, folder4]
names_folders = ["1_conv", "only_denses", "bi_lstm", "stack_conv"]

# %% [markdown]
# ## Task 1

# %%
task = "task1/"
task_string = "Task 1"

# %%
scores_arch, accu_arch = processing_metrics_dodge(list_paddings, folders, names_folders, task, n_folds)
scores_final = pd.concat([scores_arch[0], scores_arch[1], scores_arch[2], scores_arch[3]])
accu_final = pd.concat([accu_arch[0], accu_arch[1], accu_arch[2], accu_arch[3]])

# %%
scores_final
# Out:
#           enz_type  index  type_padding architecture  variable     value
# 0                0      0  post_padding       1_conv  f1-score  0.854804
# 1                1      0  post_padding       1_conv  f1-score  0.864271
# 2        micro avg      0  post_padding       1_conv  f1-score  0.859697
# 3        macro avg      0  post_padding       1_conv  f1-score  0.859538
# 4     weighted avg      0  post_padding       1_conv  f1-score  0.860010
# 5                0      0   pre_padding       1_conv  f1-score  0.865378
# 6                1      0   pre_padding       1_conv  f1-score  0.880000
# 7        micro avg      0   pre_padding       1_conv  f1-score  0.873109
# 8        macro avg      0   pre_padding       1_conv  f1-score  0.872689
# 9     weighted avg      0   pre_padding       1_conv  f1-score  0.873418
# 10               0      0   mid_padding       1_conv  f1-score  0.861732
# 11               1      0   mid_padding       1_conv  f1-score  0.865854
# 12       micro avg      0   mid_padding       1_conv  f1-score  0.863824
# 13       macro avg      0   mid_padding       1_conv  f1-score  0.863793
# 14    weighted avg      0   mid_padding       1_conv  f1-score  0.863998
# 15               0      0  strf_padding       1_conv  f1-score  0.863653
# 16               1      0  strf_padding       1_conv  f1-score  0.883721
# 17       micro avg      0  strf_padding       1_conv  f1-score  0.874484
# 18       macro avg      0  strf_padding       1_conv  f1-score  0.873687
# 19    weighted avg      0  strf_padding       1_conv  f1-score  0.874688
# 20               0      0   ext_padding       1_conv  f1-score  0.840318
# 21               1      0   ext_padding       1_conv  f1-score  0.854987
# 22       micro avg      0   ext_padding       1_conv  f1-score  0.848006
# 23       macro avg      0   ext_padding       1_conv  f1-score  0.847652
# 24    weighted avg      0   ext_padding       1_conv  f1-score  0.848384
# 25               0      0   rnd_padding       1_conv  f1-score  0.735412
# 26               1      0   rnd_padding       1_conv  f1-score  0.800241
# 27       micro avg      0   rnd_padding       1_conv  f1-score  0.772352
# 28       macro avg      0   rnd_padding       1_conv  f1-score  0.767827
# 29    weighted avg      0   rnd_padding       1_conv  f1-score  0.771059
# ...            ...    ...           ...          ...       ...       ...
# 1170             0      9   mid_padding   stack_conv    recall  0.951108
# 1171             1      9   mid_padding   stack_conv    recall  0.785491
# 1172     micro avg      9   mid_padding   stack_conv    recall  0.860041
# 1173     macro avg      9   mid_padding   stack_conv    recall  0.868299
# 1174  weighted avg      9   mid_padding   stack_conv    recall  0.860041
# 1175             0      9  strf_padding   stack_conv    recall  0.818182
# 1176             1      9  strf_padding   stack_conv    recall  0.899937
# 1177     micro avg      9  strf_padding   stack_conv    recall  0.863136
# 1178     macro avg      9  strf_padding   stack_conv    recall  0.859060
# 1179  weighted avg      9  strf_padding   stack_conv    recall  0.863136
# 1180             0      9   ext_padding   stack_conv    recall  0.927426
# 1181             1      9   ext_padding   stack_conv    recall  0.808005
# 1182     micro avg      9   ext_padding   stack_conv    recall  0.861761
# 1183     macro avg      9   ext_padding   stack_conv    recall  0.867715
# 1184  weighted avg      9   ext_padding   stack_conv    recall  0.861761
# 1185             0      9   rnd_padding   stack_conv    recall  0.770817
# 1186             1      9   rnd_padding   stack_conv    recall  0.869293
# 1187     micro avg      9   rnd_padding   stack_conv    recall  0.824966
# 1188     macro avg      9   rnd_padding   stack_conv    recall  0.820055
# 1189  weighted avg      9   rnd_padding   stack_conv    recall  0.824966
# 1190             0      9   aug_padding   stack_conv    recall  0.776929
# 1191             1      9   aug_padding   stack_conv    recall  0.859019
# 1192     micro avg      9   aug_padding   stack_conv    recall  0.822067
# 1193     macro avg      9   aug_padding   stack_conv    recall  0.817974
# 1194  weighted avg      9   aug_padding   stack_conv    recall  0.822067
# 1195             0      9  zoom_padding   stack_conv    recall  0.907563
# 1196             1      9  zoom_padding   stack_conv    recall  0.841776
# 1197     micro avg      9  zoom_padding   stack_conv    recall  0.871389
# 1198     macro avg      9  zoom_padding   stack_conv    recall  0.874670
# 1199  weighted avg      9  zoom_padding   stack_conv    recall  0.871389
#
# [4800 rows x 6 columns]

# %%
file_scores = ''.join(string for string in [absPath,'data/results/', task, "scores_final.csv"])
scores_final.to_csv(file_scores)

# %%
accu_final
# Out:
#     index      variable     value architecture
# 0       0  post_padding  0.859697       1_conv
# 1       1  post_padding  0.882050       1_conv
# 2       2  post_padding  0.878611       1_conv
# 3       3  post_padding  0.877235       1_conv
# 4       4  post_padding  0.869326       1_conv
# 5       5  post_padding  0.882737       1_conv
# 6       6  post_padding  0.858666       1_conv
# 7       7  post_padding  0.878955       1_conv
# 8       8  post_padding  0.860729       1_conv
# 9       9  post_padding  0.884113       1_conv
# 10      0   pre_padding  0.873109       1_conv
# 11      1   pre_padding  0.838033       1_conv
# 12      2   pre_padding  0.854195       1_conv
# 13      3   pre_padding  0.854195       1_conv
# 14      4   pre_padding  0.850069       1_conv
# 15      5   pre_padding  0.856602       1_conv
# 16      6   pre_padding  0.865199       1_conv
# 17      7   pre_padding  0.871733       1_conv
# 18      8   pre_padding  0.854883       1_conv
# 19      9   pre_padding  0.866919       1_conv
# 20      0   mid_padding  0.863824       1_conv
# 21      1   mid_padding  0.873796       1_conv
# 22      2   mid_padding  0.831499       1_conv
# 23      3   mid_padding  0.888927       1_conv
# 24      4   mid_padding  0.882050       1_conv
# 25      5   mid_padding  0.860041       1_conv
# 26      6   mid_padding  0.866919       1_conv
# 27      7   mid_padding  0.865887       1_conv
# 28      8   mid_padding  0.875860       1_conv
# 29      9   mid_padding  0.873453       1_conv
# ..    ...           ...       ...          ...
# 50      0   rnd_padding  0.812586   stack_conv
# 51      1   rnd_padding  0.809147   stack_conv
# 52      2   rnd_padding  0.813961   stack_conv
# 53      3   rnd_padding  0.813618   stack_conv
# 54      4   rnd_padding  0.821871   stack_conv
# 55      5   rnd_padding  0.794704   stack_conv
# 56      6   rnd_padding  0.820151   stack_conv
# 57      7   rnd_padding  0.802957   stack_conv
# 58      8   rnd_padding  0.833219   stack_conv
# 59      9   rnd_padding  0.824966   stack_conv
# 60      0   aug_padding  0.770534   stack_conv
# 61      1   aug_padding  0.768324   stack_conv
# 62      2   aug_padding  0.769208   stack_conv
# 63      3   aug_padding  0.803154   stack_conv
# 64      4   aug_padding  0.807870   stack_conv
# 65      5   aug_padding  0.760316   stack_conv
# 66      6   aug_padding  0.789399   stack_conv
# 67      7   aug_padding  0.793525   stack_conv
# 68      8   aug_padding  0.820544   stack_conv
# 69      9   aug_padding  0.822067   stack_conv
# 70      0  zoom_padding  0.863480   stack_conv
# 71      1  zoom_padding  0.859697   stack_conv
# 72      2  zoom_padding  0.868294   stack_conv
# 73      3  zoom_padding  0.868638   stack_conv
# 74      4  zoom_padding  0.859354   stack_conv
# 75      5  zoom_padding  0.828404   stack_conv
# 76      6  zoom_padding  0.864168   stack_conv
# 77      7  zoom_padding  0.882050   stack_conv
# 78      8  zoom_padding  0.862105   stack_conv
# 79      9  zoom_padding  0.871389   stack_conv
#
# [320 rows x 4 columns]

# %%
file_accu = ''.join(string for string in [absPath,'data/results/', task, "accu_final.csv"])
accu_final.to_csv(file_accu)
