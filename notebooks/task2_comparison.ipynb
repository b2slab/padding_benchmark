# %%
from __future__ import division, absolute_import

import os
import sys
import random

import numpy as np

#root
absPath = '/home/angela/padding_EBI/'
sys.path.insert(0, absPath)

#from src.Target import Target

np.random.seed(8)
random.seed(8)

from src.preprocessing import *
from src.model_architecture import *
from src.training_model import *
from src.postprocessing import *
from src.comparing_results import *
#from src.callbacks import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Defining parameters

# %%
list_paddings = ['post_padding', 'pre_padding', 'mid_padding', 
                 'strf_padding', 'ext_padding', 
                 'rnd_padding', 'aug_padding']
#list_paddings = ['aug_padding']
#list_paddings = ['post_padding', 'pre_padding', 'mid_padding', 'strf_padding', 'ext_padding', 
#                'rnd_padding']
#hierarchy of folders: annotation/dataset/architecture/n_neurs/task/padding
folder = 'EC_number/archaea/3denses/bio_neurons/'
task = "task2/"
column = "EC number"
task_string = "Task 2"

n_folds = 10

#dicti = creating_dict()

#max_lenn = 1000

#n_class = 2 #number of classes to output
#drop_per = 0.2 #Input dropout 
#n_neur = [314,77, 8]
#drop_hid = 0.5
#dict_size = len(dicti)

#batch_size = 54
#epochss = 200

# %% [markdown]
# ### Loading stuff

# %%
file_idcs_aug = os.path.join(absPath, 'data/', folder, 'idcs_aug_enz.pickle')

with open(file_idcs_aug, "rb") as input_file:
    k_aug_indices = pickle.load(input_file)
    
file_idcs = os.path.join(absPath, 'data/', folder, 'idcs_data_enz.pickle')

with open(file_idcs, "rb") as input_file:
    splitting_sets = pickle.load(input_file)

# %% [markdown]
# ## Processing results

# %%
for model_type in list_paddings:
    print("model type:", model_type)
    if model_type == "aug_padding":
        indices = k_aug_indices
    else:
        indices = splitting_sets
    for idx,i in enumerate(indices):
        print('Fold: ', idx)
        i_train, i_val, i_test = i
        #loading best model
        processing_results(folder, task, model_type, idx, i_test, "labels_task2")
# Out:
# model type: rnd_padding
# Fold:  0
# best epoch:  002
# Counter({1: 1374, 0: 222, 2: 2, 5: 1})
#
# Model Report
# Accuracy (test set): 0.3221
# Confusion matrix:
# [[ 20 158   0   0   0   0   0]
#  [ 84 493   0   0   0   0   0]
#  [ 82 228   1   0   0   0   0]
#  [ 28 145   1   0   0   0   0]
#  [  3  86   0   0   0   0   0]
#  [  4 247   0   0   0   1   0]
#  [  1  17   0   0   0   0   0]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.09      0.11      0.10       178
#            1       0.36      0.85      0.51       577
#            2       0.50      0.00      0.01       311
#            3       0.00      0.00      0.00       174
#            4       0.00      0.00      0.00        89
#            5       1.00      0.00      0.01       252
#            6       0.00      0.00      0.00        18
#
#    micro avg       0.32      0.32      0.32      1599
#    macro avg       0.28      0.14      0.09      1599
# weighted avg       0.39      0.32      0.20      1599
#
# Fold:  1
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# best epoch:  044
# Counter({1: 1106, 0: 329, 3: 62, 5: 43, 2: 35, 4: 24})
#
# Model Report
# Accuracy (test set): 0.4134
# Confusion matrix:
# [[ 76 100   1   1   0   0   0]
#  [103 462   8   3   0   1   0]
#  [ 56 236  17   0   0   2   0]
#  [ 21  99   1  52   1   0   0]
#  [ 17  51   3   1  17   0   0]
#  [ 50 151   4   5   5  37   0]
#  [  6   7   1   0   1   3   0]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.23      0.43      0.30       178
#            1       0.42      0.80      0.55       577
#            2       0.49      0.05      0.10       311
#            3       0.84      0.30      0.44       174
#            4       0.71      0.19      0.30        89
#            5       0.86      0.15      0.25       252
#            6       0.00      0.00      0.00        18
#
#    micro avg       0.41      0.41      0.41      1599
#    macro avg       0.51      0.27      0.28      1599
# weighted avg       0.54      0.41      0.35      1599
#
# Fold:  2
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# best epoch:  038
# Counter({0: 754, 1: 655, 5: 119, 3: 51, 4: 14, 2: 6})
#
# Model Report
# Accuracy (test set): 0.3371
# Confusion matrix:
# [[132  38   0   2   0   6   0]
#  [257 293   0  12   0  15   0]
#  [143 152   3   3   0  10   0]
#  [ 62  79   0  23   0  10   0]
#  [ 38  30   0   4  14   3   0]
#  [111  58   2   7   0  74   0]
#  [ 11   5   1   0   0   1   0]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.18      0.74      0.28       178
#            1       0.45      0.51      0.48       577
#            2       0.50      0.01      0.02       311
#            3       0.45      0.13      0.20       174
#            4       1.00      0.16      0.27        89
#            5       0.62      0.29      0.40       252
#            6       0.00      0.00      0.00        18
#
#    micro avg       0.34      0.34      0.34      1599
#    macro avg       0.46      0.26      0.24      1599
# weighted avg       0.48      0.34      0.31      1599
#
# Fold:  3
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# best epoch:  181
# Counter({1: 674, 2: 523, 4: 176, 0: 157, 5: 67, 6: 2})
#
# Model Report
# Accuracy (test set): 0.4121
# Confusion matrix:
# [[ 67  31  62   0  17   1   0]
#  [ 29 313 173   0  56   6   0]
#  [ 12 111 174   0  12   2   0]
#  [  8 103  48   0  15   0   0]
#  [  6  17  17   0  48   1   0]
#  [ 32  96  45   0  24  55   0]
#  [  3   3   4   0   4   2   2]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.43      0.38      0.40       178
#            1       0.46      0.54      0.50       577
#            2       0.33      0.56      0.42       311
#            3       0.00      0.00      0.00       174
#            4       0.27      0.54      0.36        89
#            5       0.82      0.22      0.34       252
#            6       1.00      0.11      0.20        18
#
#    micro avg       0.41      0.41      0.41      1599
#    macro avg       0.47      0.34      0.32      1599
# weighted avg       0.44      0.41      0.38      1599
#
# Fold:  4
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# best epoch:  079
# Counter({2: 556, 1: 519, 0: 271, 5: 137, 3: 60, 4: 54, 6: 2})
#
# Model Report
# Accuracy (test set): 0.4303
# Confusion matrix:
# [[ 86  35  34   3   8  12   0]
#  [ 85 265 193   7   4  23   0]
#  [ 35  65 194   2   4  11   0]
#  [ 16  58  60  37   0   3   0]
#  [ 22  19  20   3  21   4   0]
#  [ 24  75  46   8  16  83   0]
#  [  3   2   9   0   1   1   2]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.32      0.48      0.38       178
#            1       0.51      0.46      0.48       577
#            2       0.35      0.62      0.45       311
#            3       0.62      0.21      0.32       174
#            4       0.39      0.24      0.29        89
#            5       0.61      0.33      0.43       252
#            6       1.00      0.11      0.20        18
#
#    micro avg       0.43      0.43      0.43      1599
#    macro avg       0.54      0.35      0.36      1599
# weighted avg       0.48      0.43      0.42      1599
#
# Fold:  5
# best epoch:  194
# Counter({1: 513, 2: 408, 0: 274, 3: 264, 5: 119, 4: 19, 6: 2})
#
# Model Report
# Accuracy (test set): 0.4265
# Confusion matrix:
# [[ 80  26  40  20   0  12   0]
#  [ 81 268 145  71   0  12   0]
#  [ 36  84 162  24   0   5   0]
#  [ 27  38  31  77   0   1   0]
#  [ 10  19  13  18  19  10   0]
#  [ 39  72  14  53   0  74   0]
#  [  1   6   3   1   0   5   2]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.29      0.45      0.35       178
#            1       0.52      0.46      0.49       577
#            2       0.40      0.52      0.45       311
#            3       0.29      0.44      0.35       174
#            4       1.00      0.21      0.35        89
#            5       0.62      0.29      0.40       252
#            6       1.00      0.11      0.20        18
#
#    micro avg       0.43      0.43      0.43      1599
#    macro avg       0.59      0.36      0.37      1599
# weighted avg       0.49      0.43      0.43      1599
#
# Fold:  6
# best epoch:  189
# Counter({1: 642, 0: 294, 2: 260, 3: 204, 5: 147, 4: 48, 6: 4})
#
# Model Report
# Accuracy (test set): 0.5078
# Confusion matrix:
# [[ 83  51  24   9   0  11   0]
#  [ 82 364  56  50   2  23   0]
#  [ 51  88 147  18   0   7   0]
#  [ 26  41  16  81   0  10   0]
#  [ 13  21   3   7  42   3   0]
#  [ 33  73  14  38   3  91   0]
#  [  6   4   0   1   1   2   4]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.28      0.47      0.35       178
#            1       0.57      0.63      0.60       577
#            2       0.57      0.47      0.51       311
#            3       0.40      0.47      0.43       174
#            4       0.88      0.47      0.61        89
#            5       0.62      0.36      0.46       252
#            6       1.00      0.22      0.36        18
#
#    micro avg       0.51      0.51      0.51      1599
#    macro avg       0.62      0.44      0.48      1599
# weighted avg       0.55      0.51      0.51      1599
#
# Fold:  7
# best epoch:  040
# Counter({0: 864, 2: 313, 3: 177, 1: 161, 5: 55, 4: 29})
#
# Model Report
# Accuracy (test set): 0.2752
# Confusion matrix:
# [[128   7  21  20   0   2   0]
#  [325  86 138  26   0   2   0]
#  [185  18  94  14   0   0   0]
#  [ 82   8  30  54   0   0   0]
#  [ 38   5   8  11  27   0   0]
#  [ 93  36  20  50   2  51   0]
#  [ 13   1   2   2   0   0   0]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.15      0.72      0.25       178
#            1       0.53      0.15      0.23       577
#            2       0.30      0.30      0.30       311
#            3       0.31      0.31      0.31       174
#            4       0.93      0.30      0.46        89
#            5       0.93      0.20      0.33       252
#            6       0.00      0.00      0.00        18
#
#    micro avg       0.28      0.28      0.28      1599
#    macro avg       0.45      0.28      0.27      1599
# weighted avg       0.50      0.28      0.28      1599
#
# Fold:  8
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# best epoch:  061
# Counter({2: 627, 0: 369, 1: 336, 3: 148, 5: 101, 4: 15, 6: 3})
#
# Model Report
# Accuracy (test set): 0.3777
# Confusion matrix:
# [[ 82  22  55  15   0   4   0]
#  [130 195 218  25   0   9   0]
#  [ 68  39 179  19   0   6   0]
#  [ 31  16  69  56   0   2   0]
#  [ 38  15  18   4  13   0   1]
#  [ 17  49  81  28   0  77   0]
#  [  3   0   7   1   2   3   2]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.22      0.46      0.30       178
#            1       0.58      0.34      0.43       577
#            2       0.29      0.58      0.38       311
#            3       0.38      0.32      0.35       174
#            4       0.87      0.15      0.25        89
#            5       0.76      0.31      0.44       252
#            6       0.67      0.11      0.19        18
#
#    micro avg       0.38      0.38      0.38      1599
#    macro avg       0.54      0.32      0.33      1599
# weighted avg       0.51      0.38      0.38      1599
#
# Fold:  9
# best epoch:  061
# Counter({2: 635, 0: 366, 1: 356, 3: 133, 5: 96, 4: 12, 6: 1})
#
# Model Report
# Accuracy (test set): 0.3665
# Confusion matrix:
# [[ 78  33  55   8   0   4   0]
#  [151 186 211  21   0   8   0]
#  [ 53  44 187  22   0   5   0]
#  [ 32  19  72  48   0   3   0]
#  [ 26  27  20   4  12   0   0]
#  [ 24  46  79  29   0  74   0]
#  [  2   1  11   1   0   2   1]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.21      0.44      0.29       178
#            1       0.52      0.32      0.40       577
#            2       0.29      0.60      0.40       311
#            3       0.36      0.28      0.31       174
#            4       1.00      0.13      0.24        89
#            5       0.77      0.29      0.43       252
#            6       1.00      0.06      0.11        18
#
#    micro avg       0.37      0.37      0.37      1599
#    macro avg       0.59      0.30      0.31      1599
# weighted avg       0.50      0.37      0.37      1599
#
# model type: aug_padding
# Fold:  0
# best epoch:  192
# Counter({1: 3539, 2: 3421, 3: 1205, 0: 683, 5: 487, 4: 217, 6: 42})
#
# Model Report
# Accuracy (test set): 0.5303
# Confusion matrix:
# [[ 427  217  309   96    1   18    0]
#  [  84 2016 1141  206    0   15    0]
#  [  37  318 1391  114    1    5    0]
#  [  40  189  251  557    1    6    0]
#  [  16  138  101   63  214    2    0]
#  [  71  641  193  166    0  441    0]
#  [   8   20   35    3    0    0   42]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.40      0.49      1068
#            1       0.57      0.58      0.58      3462
#            2       0.41      0.75      0.53      1866
#            3       0.46      0.53      0.50      1044
#            4       0.99      0.40      0.57       534
#            5       0.91      0.29      0.44      1512
#            6       1.00      0.39      0.56       108
#
#    micro avg       0.53      0.53      0.53      9594
#    macro avg       0.71      0.48      0.52      9594
# weighted avg       0.61      0.53      0.53      9594
#
# Fold:  1
# best epoch:  197
# Counter({1: 3842, 2: 2567, 3: 1955, 0: 577, 5: 412, 4: 196, 6: 45})
#
# Model Report
# Accuracy (test set): 0.5082
# Confusion matrix:
# [[ 398  247  184  234    0    5    0]
#  [  69 2089  779  514    0   11    0]
#  [  28  442 1149  241    1    5    0]
#  [  17  192  210  618    0    7    0]
#  [  16  136   62  126  194    0    0]
#  [  45  710  162  211    1  383    0]
#  [   4   26   21   11    0    1   45]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.37      0.48      1068
#            1       0.54      0.60      0.57      3462
#            2       0.45      0.62      0.52      1866
#            3       0.32      0.59      0.41      1044
#            4       0.99      0.36      0.53       534
#            5       0.93      0.25      0.40      1512
#            6       1.00      0.42      0.59       108
#
#    micro avg       0.51      0.51      0.51      9594
#    macro avg       0.70      0.46      0.50      9594
# weighted avg       0.61      0.51      0.50      9594
#
# Fold:  2
# best epoch:  172
# Counter({1: 3998, 2: 3253, 3: 1103, 0: 514, 5: 457, 4: 242, 6: 27})
#
# Model Report
# Accuracy (test set): 0.5255
# Confusion matrix:
# [[ 394  290  278  100    0    6    0]
#  [  49 2190 1017  183    0   23    0]
#  [  32  431 1292   98    5    8    0]
#  [   8  216  294  511    2   13    0]
#  [  11  119  119   62  223    0    0]
#  [  18  716  218  144   11  405    0]
#  [   2   36   35    5    1    2   27]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.37      0.50      1068
#            1       0.55      0.63      0.59      3462
#            2       0.40      0.69      0.50      1866
#            3       0.46      0.49      0.48      1044
#            4       0.92      0.42      0.57       534
#            5       0.89      0.27      0.41      1512
#            6       1.00      0.25      0.40       108
#
#    micro avg       0.53      0.53      0.53      9594
#    macro avg       0.71      0.45      0.49      9594
# weighted avg       0.61      0.53      0.52      9594
#
# Fold:  3
# best epoch:  188
# Counter({1: 3551, 2: 2838, 3: 1833, 0: 577, 5: 492, 4: 258, 6: 45})
#
# Model Report
# Accuracy (test set): 0.5046
# Confusion matrix:
# [[ 403  251  225  172    6   11    0]
#  [  79 1906  986  471    1   19    0]
#  [  37  346 1222  236    9   16    0]
#  [  25  212  182  610    4   11    0]
#  [  11  139   62   93  228    1    0]
#  [  20  676  141  240    8  427    0]
#  [   2   21   20   11    2    7   45]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.38      0.49      1068
#            1       0.54      0.55      0.54      3462
#            2       0.43      0.65      0.52      1866
#            3       0.33      0.58      0.42      1044
#            4       0.88      0.43      0.58       534
#            5       0.87      0.28      0.43      1512
#            6       1.00      0.42      0.59       108
#
#    micro avg       0.50      0.50      0.50      9594
#    macro avg       0.68      0.47      0.51      9594
# weighted avg       0.59      0.50      0.50      9594
#
# Fold:  4
# best epoch:  186
# Counter({1: 3914, 2: 3273, 3: 1271, 5: 590, 0: 348, 4: 175, 6: 23})
#
# Model Report
# Accuracy (test set): 0.5082
# Confusion matrix:
# [[ 312  281  311  120    1   43    0]
#  [  11 2168 1016  230    0   37    0]
#  [   5  481 1248  115    0   17    0]
#  [   8  241  281  492    0   22    0]
#  [   0  141   82  135  170    6    0]
#  [  10  566  295  174    4  463    0]
#  [   2   36   40    5    0    2   23]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.29      0.44      1068
#            1       0.55      0.63      0.59      3462
#            2       0.38      0.67      0.49      1866
#            3       0.39      0.47      0.43      1044
#            4       0.97      0.32      0.48       534
#            5       0.78      0.31      0.44      1512
#            6       1.00      0.21      0.35       108
#
#    micro avg       0.51      0.51      0.51      9594
#    macro avg       0.71      0.41      0.46      9594
# weighted avg       0.60      0.51      0.50      9594
#
# Fold:  5
# best epoch:  200
# Counter({2: 3838, 1: 3405, 3: 1178, 5: 468, 0: 423, 4: 252, 6: 30})
#
# Model Report
# Accuracy (test set): 0.5123
# Confusion matrix:
# [[ 311  263  368  112    2   12    0]
#  [  34 1917 1286  212    2   11    0]
#  [  14  345 1419   87    0    1    0]
#  [  21  180  264  569    3    7    0]
#  [   5  127   91   73  236    2    0]
#  [  32  551  366  121    9  433    0]
#  [   6   22   44    4    0    2   30]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.29      0.42      1068
#            1       0.56      0.55      0.56      3462
#            2       0.37      0.76      0.50      1866
#            3       0.48      0.55      0.51      1044
#            4       0.94      0.44      0.60       534
#            5       0.93      0.29      0.44      1512
#            6       1.00      0.28      0.43       108
#
#    micro avg       0.51      0.51      0.51      9594
#    macro avg       0.72      0.45      0.49      9594
# weighted avg       0.62      0.51      0.51      9594
#
# Fold:  6
# best epoch:  192
# Counter({1: 3213, 2: 2762, 3: 2081, 0: 704, 5: 540, 4: 242, 6: 52})
#
# Model Report
# Accuracy (test set): 0.4979
# Confusion matrix:
# [[ 416  224  213  207    1    7    0]
#  [ 112 1873  882  570    0   25    0]
#  [  77  351 1118  312    0    8    0]
#  [  39  170  219  602    0   14    0]
#  [  14  112   38  123  239    8    0]
#  [  46  468  264  255    2  477    0]
#  [   0   15   28   12    0    1   52]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.39      0.47      1068
#            1       0.58      0.54      0.56      3462
#            2       0.40      0.60      0.48      1866
#            3       0.29      0.58      0.39      1044
#            4       0.99      0.45      0.62       534
#            5       0.88      0.32      0.46      1512
#            6       1.00      0.48      0.65       108
#
#    micro avg       0.50      0.50      0.50      9594
#    macro avg       0.68      0.48      0.52      9594
# weighted avg       0.59      0.50      0.51      9594
#
# Fold:  7
# best epoch:  138
# Counter({1: 3794, 2: 2666, 3: 1647, 0: 677, 5: 521, 4: 247, 6: 42})
#
# Model Report
# Accuracy (test set): 0.4989
# Confusion matrix:
# [[ 375  329  192  151    1   20    0]
#  [ 117 1991  909  426    1   18    0]
#  [  68  417 1120  251    2    8    0]
#  [  54  221  188  568    2   11    0]
#  [  11  126   53  103  236    5    0]
#  [  49  676  188  142    3  454    0]
#  [   3   34   16    6    2    5   42]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.35      0.43      1068
#            1       0.52      0.58      0.55      3462
#            2       0.42      0.60      0.49      1866
#            3       0.34      0.54      0.42      1044
#            4       0.96      0.44      0.60       534
#            5       0.87      0.30      0.45      1512
#            6       1.00      0.39      0.56       108
#
#    micro avg       0.50      0.50      0.50      9594
#    macro avg       0.67      0.46      0.50      9594
# weighted avg       0.57      0.50      0.50      9594
#
# Fold:  8
# best epoch:  197
# Counter({1: 3729, 2: 3392, 3: 1030, 5: 588, 0: 513, 4: 279, 6: 63})
#
# Model Report
# Accuracy (test set): 0.5294
# Confusion matrix:
# [[ 365  335  275   60    6   27    0]
#  [  67 2022 1146  195    1   31    0]
#  [  19  378 1360   84    0   25    0]
#  [  16  223  263  523    0   19    0]
#  [  12   92   98   60  268    4    0]
#  [  32  670  222  104    4  479    1]
#  [   2    9   28    4    0    3   62]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.34      0.46      1068
#            1       0.54      0.58      0.56      3462
#            2       0.40      0.73      0.52      1866
#            3       0.51      0.50      0.50      1044
#            4       0.96      0.50      0.66       534
#            5       0.81      0.32      0.46      1512
#            6       0.98      0.57      0.73       108
#
#    micro avg       0.53      0.53      0.53      9594
#    macro avg       0.70      0.51      0.56      9594
# weighted avg       0.60      0.53      0.53      9594
#
# Fold:  9
# best epoch:  168
# Counter({1: 3822, 2: 3152, 3: 1072, 5: 620, 0: 620, 4: 270, 6: 38})
#
# Model Report
# Accuracy (test set): 0.5253
# Confusion matrix:
# [[ 375  329  237   91    0   36    0]
#  [ 110 2105 1052  167    2   26    0]
#  [  54  447 1225  116    4   20    0]
#  [  25  215  258  525    1   20    0]
#  [  10  117   99   42  261    5    0]
#  [  44  586  244  125    2  511    0]
#  [   2   23   37    6    0    2   38]]
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.35      0.44      1068
#            1       0.55      0.61      0.58      3462
#            2       0.39      0.66      0.49      1866
#            3       0.49      0.50      0.50      1044
#            4       0.97      0.49      0.65       534
#            5       0.82      0.34      0.48      1512
#            6       1.00      0.35      0.52       108
#
#    micro avg       0.53      0.53      0.53      9594
#    macro avg       0.69      0.47      0.52      9594
# weighted avg       0.59      0.53      0.52      9594

# %% [markdown]
# ## Plotting

# %% [markdown]
# ### History

# %%
#hay que modificar esta funcion para q acerque task
df_his,k = collecting_metrics_folds("history", list_paddings, folder, task, n_folds)
plotting_history(df_his, task_string, folder, task, k)

# %% [markdown]
# ### Accuracy (test)

# %%
scores_final, accu = processing_metrics_results(list_paddings, folder, task, n_folds)

# %%
plotting_auc_acc_boxplots(accu, folder, "accuracy", n_folds, task_string, task)
# Out:
# /home/angela/.local/lib/python3.6/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/ggplot.py:706: UserWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units))
# /home/angela/.local/lib/python3.6/site-packages/plotnine/ggplot.py:707: UserWarning: Filename: /home/angela/padding_EBI/data/results/EC_number/archaea/3denses/bio_neurons/task2/test_accuracy_comparison.pdf
#   warn('Filename: {}'.format(filename))
# /home/angela/.local/lib/python3.6/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:69: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(val) and not is_string(val):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:69: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(val) and not is_string(val):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/ggplot.py:722: MatplotlibDeprecationWarning:
# The frameon kwarg was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use facecolor instead.
#   fig.savefig(filename, **fig_kwargs)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:69: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(val) and not is_string(val):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:69: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(val) and not is_string(val):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (8774324736597)>

# %% [markdown]
# ### Scores

# %%
plotting_scores_boxplots(scores_final, folder, n_folds, task_string, task)
# Out:
# /home/angela/.local/lib/python3.6/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/ggplot.py:706: UserWarning: Saving 24 x 16 in image.
#   from_inches(height, units), units))
# /home/angela/.local/lib/python3.6/site-packages/plotnine/ggplot.py:707: UserWarning: Filename: /home/angela/padding_EBI/data/results/EC_number/archaea/3denses/bio_neurons/task2/scores.pdf
#   warn('Filename: {}'.format(filename))
# /home/angela/.local/lib/python3.6/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/stats/stat.py:310: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   stats = pd.concat(stats, axis=0, ignore_index=True)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:629: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat(lst, axis=axis, ignore_index=True)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:69: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(val) and not is_string(val):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:69: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(val) and not is_string(val):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:69: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(val) and not is_string(val):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:69: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(val) and not is_string(val):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:69: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(val) and not is_string(val):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:69: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(val) and not is_string(val):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:69: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(val) and not is_string(val):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# ...
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:69: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(val) and not is_string(val):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:69: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(val) and not is_string(val):
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# /home/angela/.local/lib/python3.6/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (8774328441913)>
